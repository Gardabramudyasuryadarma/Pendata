# %% [markdown]
# # Tugas 2

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib as plt
from scipy.spatial.distance import cityblock

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-791f61a8-b5b3-4b84-8344-e57a300e3788" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-791f61a8-b5b3-4b84-8344-e57a300e3788">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel("pendata2.xlsx")

print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-41214a0d4462> in <module>
# ----> 1 data=pd.read_excel("pendata2.xlsx")
#       2
#       3 print(data)
#
# NameError: name 'pd' is not defined

# %%
print("Banyak baris/objek data", data.shape[0])
print("Banyak kolom/atribut data", data.shape[1])
# Out:
# Banyak baris/objek data 4
# Banyak kolom/atribut data 4

# %%
j1 = data['umur'].values[0]
x1 = data['umur'].values[1]

a = (j1,x1)
print(a)
# Out:
# (25, 31)

# %%
selisih = np.diff(a)
print(selisih)
# Out:
# [6]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94c1ea4f-d70b-4ca8-930b-bee529083296" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94c1ea4f-d70b-4ca8-930b-bee529083296">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel("pendata2.xlsx")

print(data)
# Out:
#   Tempat tinggal        status riwayat pendidikan  umur
# 0       lamongan       menikah                 SD    25
# 1       surabaya  belummenikah                SMP    31
# 2        jakarta       menikah                SMA    22
# 3          jogja       menikah              S!/D4    22

# %%
df = pd.read_excel("pendata2.xlsx")
 


data['status'].replace(['menikah', 'belummenikah'],
                        [1, 0], inplace=True)

# %%
df = pd.read_excel("pendata2.xlsx")
 


data['riwayat pendidikan'].replace(['SD','SMP','SMA','S!/D4'],
                        [1, 0 ,2 ,3], inplace=True)

# %%
bin1 = data['riwayat pendidikan']
bin2 = data['status']

print(bin1,bin2)
# Out:
# 0    1
# 1    0
# 2    2
# 3    3
# Name: riwayat pendidikan, dtype: int64 0    1
# 1    0
# 2    1
# 3    1
# Name: status, dtype: int64

# %%
from scipy.spatial.distance import hamming

# %%
hamming_distance = hamming(bin1,bin2)

print(hamming_distance)
# Out:
# 0.5
